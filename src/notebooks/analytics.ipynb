# %% [markdown]
# ### Análise do tipos de veículos

# %% [markdown]
# ### Conecta ao Banco

# %%
import pandas as pd
from sqlalchemy import create_engine
import matyplotlib.pyplot as plt
import seaborn as sns

db_url = create_engine('postgresql://admin:uber.10@db:5432/uberdb')

try:
    engine = create_engine(db_url)
    df = pd.read_sql_query('SELECT * FROM "UBER"', con=engine)
    print("Conexão ok")
except Exception as e:
    printf(f"Erro ao conectar com o banco de dados: {e}")

# %% [markdown]
# Análise de Regressão
