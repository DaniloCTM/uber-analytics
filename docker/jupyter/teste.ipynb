# %%
from sqlalchemy import create_engine, text

engine = create_engine('postgresql://admin:uber.10@db:5432/uberdb')
connection = engine.connect()
print("Conectado ao PostgreSQL!")
# Out:
# ✅ Conectado ao PostgreSQL!
